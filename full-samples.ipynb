# %%
import pandas as pd 
import numpy as np
import os
import math
import matplotlib.pyplot as plt

plt.rcParams['savefig.dpi'] = 300 
plt.rcParams['figure.dpi'] = 300

# %%
# the folder that contain the figures
FIG_DIR = 'figure'

path = os.path.join(os.getcwd(), FIG_DIR)
# check whether the directory exist or not
if not os.path.exists(path):
    os.mkdir(path)

def plot_line(a, data,COLOR,LINESTYLE,MAKER,LABEL):
    plt.plot(a, data,color=COLOR,linestyle=LINESTYLE, 
             markersize=15, 
             markeredgewidth =1.5,
             markerfacecolor='none',
             marker=MAKER,label = LABEL)

# %%
import numpy as np

filename = os.path.join(path, 's1')

plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0

# this is fig size
plt.rcParams["figure.figsize"] = (8,5)
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.3


x_labels = [ "45", "50", "55","60"]
x =list(range(len(x_labels)))

# configure the width
total_width, n = 0.4,2
width = total_width / n

weighted_density = [228.8772255,201.0200863,262.9089933,280.0634708]
weight_rating = [4.331128,4.45061825,4.20970025,4.149943]
abcore_density = [409.283535,420.870374,431.687559,440.572795]
abcore_rating = [3.392919,3.383857,3.37509,3.366231]
G5_density = [4.119263,4.119263,4.119263,4.119263]
G5_rating = [4.15694,4.15694,4.15694,4.15694]
truss_density = [261.140222,270.158941,278.150888,285.78591]
bitruss_rating = [3.475264,3.475675,3.476124,3.476569]


bar1 = plt.bar([i - 0.30 for i in x],weighted_density, width = width,label = "SC", linewidth=1.5 , fc = 'black',edgecolor="black")

bar2 = plt.bar([i - 0.10 for i in x],abcore_density , width = width,label =r"$(\alpha,\beta)$-core"  , linewidth=1.5,
               color="w" ,edgecolor="black",hatch="\\\\"*2) 

bar3 = plt.bar([i + 0.10 for i in x],truss_density , width = width,label = "bitruss" , linewidth=1.5,
               color="w" ,edgecolor="black")

bar4 = plt.bar([i + 0.30 for i in x],G5_density , width = width, label = r"$C_{4}$" , linewidth=1.5,
               color="w" ,edgecolor="black",hatch="..")

i=0
for rect in bar1:
    height = rect.get_height()
#     plt.text(rect.get_x()-rect.get_width()/5-0.16, 1.1*height, '%.2f' % weight_rating[i],fontsize=14)
    plt.text(rect.get_x()-rect.get_width()/5-0.07, 1.1*height, '%.2f' % weight_rating[i],fontsize=14)
    i+= 1
    
i=0
for rect in bar2:
    height = rect.get_height()
    plt.text(rect.get_x()-rect.get_width()/5, 1.1*height, '%.2f' % abcore_rating[i],fontsize=14)
    i+= 1
i=0
for rect in bar3:
    height = rect.get_height()
    plt.text(rect.get_x()-rect.get_width()/5+0.05, 1.1*height, '%.2f' % bitruss_rating[i],fontsize=14)
    i+= 1
i=0
for rect in bar4:
    height = rect.get_height()
    plt.text(rect.get_x()-rect.get_width()/5+0.05, 1.08*height, '%.2f' % G5_rating[i],fontsize=14)
    i+= 1

# my_y_ticks = np.arange(0, 601, 100)
# plt.yticks(my_y_ticks)
plt.yscale('log')
plt.ylim(1, 2*pow(10,3))
plt.xticks( fontsize=20) #rotation=-15,
plt.yticks(fontsize=20)
plt.ylabel('Bipartite graph density',fontsize=20)
plt.xlabel('t',fontsize=20)
plt.legend(fontsize=18 ,ncol=4,loc="upper center", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1) 
plt.xticks(x, x_labels)
ax.tick_params(axis="x",direction="in", left="off",labelleft="on")
plt.savefig(filename, bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1eac3609d086> in <module>
#      74 plt.legend(fontsize=18 ,ncol=4,loc="upper center", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1)
#      75 plt.xticks(x, x_labels)
# ---> 76 ax.tick_params(axis="x",direction="in", left="off",labelleft="on")
#      77 plt.savefig(filename, bbox_inches = 'tight')
#
# NameError: name 'ax' is not defined

# %%
# query performence
# default query barplot 
import numpy as np

filename = os.path.join(path, 's2')

fig = plt.figure(1, figsize=(6.8*2, 4.0))
ax = fig.add_subplot(111)


plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.3


default=[
['BS',0.13498,0.0861],
['GH',0.079098,0.052056],
['SO',0.233532,0.195663],
['LS',0.67481,0.408521],
['DT',0.795501,0.456255],
['AR',1.003714,0.62751],
['PA',3.725007,1.310021],
['ML',4.815597,4.625074],
['DUI',18.530698,20.253232],
['EN',13.986873,6.890248],
['DTI',9.218351,5.897713]
]
default_df=pd.DataFrame(default)
name_list = default_df[0].tolist()
peel_list= default_df[1].tolist()
expand_list= default_df[2].tolist()

x = np.arange(len(name_list))


total_width, n = 0.9, 4
width = total_width / (n+1)

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, peel_list, width=width, label="peel",linewidth=1, edgecolor='black',
        fc = 'black')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width, expand_list, width=width, label="expand",linewidth=0.5,edgecolor='black',hatch="\\\\"*2,
        fc = 'w')

plt.xticks(x+0.5*width,name_list)

plt.yscale('log')
plt.yscale('log')
plt.ylim(0.001,2*pow(10,2))
plt.ylabel("Time(s)",fontsize = 20)
# plt.yticks(pos, labels)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Datasets",fontsize=20)


plt.legend(fontsize=18 ,ncol=2,loc="upper left", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1) 
plt.savefig(filename, bbox_inches='tight')
plt.show()

# %%
import numpy as np

filename = os.path.join(path, 's3')


fig = plt.figure(1, figsize=(6.8*2, 4.0))
ax = fig.add_subplot(111)


plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.3


default=[
['DBPedia',0.02, 0.015, 0.008],
['Twitter',0.374,0.209, 0.147],
['Amazon',1.179,0.594,0.155],
['Wiki-fr',5.141,3.496,211.082],
['Live-journal',59.585,37.773,1697.759],
['Wiki-en',74.76,39.067,1760.637],
['Delicious',133.847,51.11,158.017],
['Tracker',71.656,35.601,10654.722],
['Orkut',668.544,282.513,8219.795],
['Bi-twitter',1215.512,525.095,22631.396],
['Bi-sk',222.425,135.963,7717.348],
['Bi-uk',599.067,324.104,16711.177]
]
default_df=pd.DataFrame(default)
name_list = default_df[0].tolist()
IG_BS = default_df[1].tolist()
IG_ADV = default_df[2].tolist()
SE = default_df[3].tolist()

x = np.arange(len(name_list))
# x =list(range(len(our_list)))
total_width, n = 0.9, 3
width = total_width / (n+1)

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, SE, width=width, label="BS",linewidth=0.5,color="w" ,edgecolor="black")

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width, IG_BS, width=width, label="IG",linewidth=0.5,edgecolor='black',hatch="/"*2,
        fc = 'w')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width+width, IG_ADV, width=width, label=r"IG$^+$",linewidth=0.5,edgecolor='black',hatch="\\\\",
        fc = 'w')


plt.xticks(x+1*width, name_list,rotation=-50)

plt.yscale('log')
plt.yscale('log')
plt.ylim(0.001,4*pow(10,5))
plt.ylabel("Time Cost (sec)",fontsize = 20)
# plt.yticks(pos, labels)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# plt.xlabel("Datasets",fontsize=20)

plt.legend(fontsize=18 ,ncol=3,loc="upper left", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1) 
plt.savefig(filename, bbox_inches='tight')
plt.show()

# %%
#vary ab time
filename = os.path.join(path, 's4')


plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5


peel = [0.379586,0.189762,0.05974,0.029819,0.015993]
expand = [0.170803,0.101698,0.064029,0.051474,0.042497]


index_x = ['0.1', '0.3', '0.5', '0.7','0.9']
plot_line(index_x,peel,'black','dashed', "o", "peel")
plot_line(index_x,expand,'black','dashed', "x", "expand")

font2 = {'weight': 'normal', 'size': 20}
plt.yscale('log')
plt.ylim(0.01,2*pow(10,0))
plt.ylabel("Time(s)",fontsize = 20)
plt.xlabel('c',fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(loc='upper center',ncol=2, frameon=False, prop = font2) 
# plt.show()
plt.savefig(filename, bbox_inches='tight')

# %%
"""
Example of overload sample
"""

filename = os.path.join(path, 's5')


fig,ax=plt.subplots()

labels = ['0.01', '0.1', '0.5', '1','2']

x =list(range(len(labels)))
total_width, n = 0.8,2
width = total_width / n


IG_BS = [97.59, 126.68, 133.847, 137.834, 139.816]
IG_ADV = [21.501, 40.843, 51.11, 58.833, 64.288]
delc = [0.099, 0.189, 0.496, 0.787, 1.423]

IG = plt.bar([i - 0.2 for i in x], IG_BS , width = width ,label = "IG" , linewidth=1.5,
               fc = 'w' ,edgecolor="black", hatch="/" * 2)

DELC1 = plt.bar([i - 0.2 for i in x], delc , width = width, bottom = IG_BS ,  label="DelOver", linewidth=1.5, color="b" ,edgecolor="blue")

IGA = plt.bar([i + 0.2for i in x],IG_ADV , width = width, label = r"IG$^+$" , linewidth=1.5,
               fc = 'w' ,edgecolor="black",hatch="\\"*2)

DELC2 = plt.bar([i + 0.2for i in x], delc , width = width, bottom = IG_ADV, label="DelOver", linewidth=1.5, color="b" ,edgecolor="blue")


# if set log, then log scale
# plt.yscale('log')

plt.ylim(10,1.8*pow(10,2))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Time Cost (sec)',fontsize=20)

legend = ax.legend((bar1, bar2, DELC1, DELC2),
                   ("IG", r"IG$^+$", "DEL"),
                   loc='upper right',fontsize=16 ,ncol=3,frameon = 0,
                   handlelength = 1.6, handletextpad = 0.4, labelspacing = 0.2, columnspacing=0.5,bbox_to_anchor=(1, 1) )

plt.xticks(x,labels)
plt.xlabel("Batch size b (%)",fontsize = 20)
ax.tick_params(axis="x",direction="in", left="off",labelleft="on")

plt.savefig(filename, bbox_inches = 'tight')

# %%
filename = os.path.join(path, 's6')


plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
plt.rcParams['figure.figsize'] = (10.0, 5.0)

index_x = ['0.01', '0.1', '0.5', '1','2']

font2 = {'weight': 'normal', 'size': 16}

deli = [24003243,229322487,1128774902,2242179336,4419529910]
trac = [7965342754,79734093105,398225874432,789440289145,1556022219637]
bisk = [49329834773,489204651509,2430026018256,4822112916786,9498679768042]
biuk = [193393717757,1953145884070,9732582616154,19271163835940,37966518238769]


plot_line(index_x, deli, 'black','dashed', "p", "Delicious")
plot_line(index_x, trac, 'black','dashed', "o", "Tracker")

plot_line(index_x, bisk, 'black','dashed', '<', "Bi-sk")
plot_line(index_x, biuk, 'black','dashed', '>', "Bi-uk")

# plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
#            ncol=2, mode="expand", borderaxespad=0.)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)


plt.yscale('log')
plt.ylim(10000000,9*pow(10,15))

plt.ylabel("Affected butterflies",fontsize = 20)
plt.xlabel(r"Batch size b (%)",fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(ncol=4, bbox_to_anchor=(0.02, 0.98), loc='upper left', borderaxespad=0., prop = font2) 
plt.savefig(filename, bbox_inches='tight')

# %%
"""
another overlap
"""

filename = os.path.join(path, 's6')


plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
plt.rcParams['figure.figsize'] = (6.4, 4.8)


x_labels = ["1", "8", "16","24", "32"]
x =list(range(len(x_labels)))

total_width, n = 0.8,2
width = total_width / n


GC=[123.574,21.423,12.685,10.087,9.290]
count=[133.859,27.771,17.773,15.067,14.256]
IG_BS_GC=[43.768,9.380,5.972,4.227,4.009]
IG_ADV_count=[50.857,13.836,10.442,9.689,8.900]


count_bar = plt.bar([i - 0.2 for i in x], count , width = width ,label = "GC" , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black") 


IGA_bar = plt.bar([i + 0.2for i in x], IG_ADV_count , width = width, label = "IG-BS"  , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black")


IGB_bar = plt.bar([i + 0.2for i in x],IG_BS_GC , width = width, label = "IG-ADV" , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black",hatch="\\\\")

GC_bar = plt.bar([i - 0.2 for i in x],GC , width = width ,label = "count"  , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black",hatch="//") 



my_y_ticks = np.arange(0, 180, 30)
plt.yticks(my_y_ticks)

plt.xticks(fontsize=20) #rotation=-15,
plt.yticks(fontsize=20)
plt.ylabel('Time Cost (sec)',fontsize=20)
plt.xlabel('t',fontsize=20)

plt.legend((count_bar,GC_bar, IGA_bar, IGB_bar,),
                   ("IG-GC","IG-Count",r"IG$^+$-GC",r"IG$^+$-Count",),
                   loc='upper right',fontsize=16 ,ncol=1,frameon = 0,
                   handlelength = 1.6, 
                   handletextpad = 0.4, 
                   labelspacing = 0.2, 
                   columnspacing=0.5,bbox_to_anchor=(1, 1))

plt.xticks(x, x_labels)

plt.savefig(filename, bbox_inches = 'tight')

# %%
"""
sample to add more overlap in overlap
"""

filename = os.path.join(path, 's7')


plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
plt.rcParams['figure.figsize'] = (6.4, 4.8)

x_labels = ["1", "8", "16","24", "32"]
x =list(range(len(x_labels)))

total_width, n = 0.8,2
width = total_width / n


GC=[546.499,103.072,61.988,45.284,39.159]
count=[590.148,130.539,82.288,65.133,57.525]

IG_BS_GC=[283.090,56.939,34.134,27.588,24.039]
IG_ADV_count=[317.905,79.534,54.989,48.101,44.152]
delc = [4.878, 4.064, 3.593, 2.375, 2.287]


gc_bar = plt.bar([i - 0.2 for i in x], count , width = width ,label = "GC" , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black") 
del_bar1 = plt.bar([i - 0.2 for i in x], delc , width = width, bottom = count ,  label="DelOHD", linewidth=1.5, color="b" ,edgecolor="blue") 


ig_bar = plt.bar([i + 0.2for i in x], IG_ADV_count , width = width, label = "IG-BS"  , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black")

del_bar2 = plt.bar([i + 0.2for i in x], delc , width = width, bottom = IG_ADV_count, label="DelOHD", linewidth=1.5, color="b" ,edgecolor="blue") 



iga_bar = plt.bar([i + 0.2for i in x],IG_BS_GC , width = width, label = "IG-ADV" , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black",hatch="\\\\")


count_bar = plt.bar([i - 0.2 for i in x],GC , width = width ,label = "count"  , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black",hatch="//") 


my_y_ticks = np.arange(0, 750, 150)
plt.yticks(my_y_ticks)

plt.xticks( fontsize=20) #rotation=-15,
plt.yticks(fontsize=20)
plt.ylabel('Time Cost (sec)',fontsize=20)
plt.xlabel('t',fontsize=20)

plt.legend((gc_bar,count_bar, ig_bar, iga_bar, del_bar1, del_bar2),
                   ("IG-GC","IG-Count",r"IG$^+$-GC",r"IG$^+$-Count", "DelOHD"),
                   loc='upper right',fontsize=16 ,ncol=1)

plt.xticks(x,x_labels)
plt.savefig(filename, bbox_inches = 'tight')

# %%
"""
sample to change x label and add a vertical line
"""
filename = os.path.join(path, 's8')

plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
index_x = ['$2^1$', '$2^2$', '$2^3$','$2^4$','$2^5$','$2^6$','$2^7$', '$2^8$', '$2^9$']
font2 = {'weight': 'normal', 'size': 18}

DEL = [7.868, 25.69278, 27.46308, 43.12188, 77.82708, 156.20548, 273.74848, 575.50148, 1391.21148]
INS = [3.9164, 9.07341, 10.09079, 20.09943, 38.63913, 78.91473, 148.50713, 316.74713, 754.23613]
BU = [712.76646,712.76646,712.76646,712.76646,712.76646,712.76646,712.76646, 712.76646, 712.76646]


plot_line(index_x, INS, 'black','dashed', "o", "HM-Ins")
plot_line(index_x, DEL, 'black','dashed', "x", "HM-Del")
plot_line(index_x, BU, 'black','dashed', "+", "HC-BU")

# add line with color
plt.axvline(x='$2^9$', ymin=0, ymax=10^3, color='blue', ls='--')


plt.yscale('log')

plt.ylim(1, 1*pow(10,5))
plt.ylabel("Time Cost (sec)",fontsize = 20)
plt.xlabel(r"x",fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(loc='upper left',ncol=3, frameon=False, prop = font2) 
plt.savefig(filename, bbox_inches='tight')

# %%
# this is two times test for update
hmdel = pd.read_csv("/mnt/c/Users/lsy/Desktop/graph/del.csv")
hmins = pd.read_csv("/mnt/c/Users/lsy/Desktop/graph/ins.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-93a8e62f4da8> in <module>
#       1 # this is two times test for update
# ----> 2 hmdel = pd.read_csv("/mnt/c/Users/lsy/Desktop/graph/del.csv")
#       3 hmins = pd.read_csv("/mnt/c/Users/lsy/Desktop/graph/ins.csv")
#
# ...

# %%
"""
The most confusing graph for update 
"""
filename = os.path.join(path, 's9')


import numpy as np


fig = plt.figure(1, figsize=(6.8*2, 4.0))
ax = fig.add_subplot(111)
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.3

# construction time
default=[
['RL', 18.75456591],
['YG', 12.9887239],
['GH', 10.4040172],
['TM', 84.4522679],
['IM', 25.8538191],
['WC', 402.244297],
['FG', 1709.70062],
['PA', 283.109613],
['ML', 12943.747],
['DUI', 61306.678]
]

default_df=pd.DataFrame(default)
name_list = default_df[0].tolist()
index_time = default_df[1].tolist()

x = np.arange(len(name_list))
# x =list(range(len(our_list)))
total_width, n = 0.9, 3
width = total_width / (n+1)

for i in range(len(x)):
    x[i] = x[i] + width

plt.bar(x, index_time, width=width,linewidth=1,edgecolor='black',hatch="\\\\"*2,
        fc = 'w')

for i in range(len(x)):
    x[i] = x[i] + width
    plt.boxplot(hmins[name_list[i]].tolist(), positions=[x[i] + width], showfliers=True,showcaps=True, widths=0.18, whiskerprops={"linewidth": 1})
    plt.plot([x[i] + width, x[i] + width ], [0, hmins[name_list[i]].min()], ':', color="black")

    
for i in range(len(x)):
    x[i] = x[i] + width
    plt.boxplot(hmdel[name_list[i]].tolist(), positions=[x[i] + width + width], showfliers=True,widths=0.18, whiskerprops={"linewidth": 1})
    plt.plot([x[i] + width + width, x[i] + width + width ], [0,hmdel[name_list[i]].min()], ':', color="black")
    
plt.xticks(x+0.5*width, name_list)

plt.yscale('log')
plt.yscale('log')
plt.ylim(0.001, 1*pow(10,6))
plt.ylabel("Time(s)",fontsize = 20)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Datasets",fontsize=20)


labels = []

ax.set_aspect(0.3)
plt.legend(fontsize=20 ,ncol=3,loc="upper left", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1, title='HM-BU, HM-Ins, HM-Del (from left to right)', title_fontsize = 18) 
plt.savefig(filename, bbox_inches='tight')
plt.show()

# %%
filename = os.path.join(path, 'amazon_q0.pdf')


plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5


fig, ax = plt.subplots()

index_x = ['1','2','4','6','8','10','20','40','60']

font2 = {'weight': 'normal', 'size': 16}

time = [6574.894331,3084.307753,1575.000016,1049.337325,777.2911115,631.3773627,343.0305325,211.7561193,145.5545044]
su = [1,2.131724477,4.174536042,6.265758564,8.458728311,10.41357312,19.16708196,31.0493711,45.17135598]


ax.set_ylabel('Time Cost (sec)',fontsize = 20)

# ax1.set_yticklabels(labels=['y1', 'y2'], rotation = 0, fontsize = 'medium')
ax.tick_params(axis='y', which='major', labelsize=20)
ax.set_xticklabels(labels=index_x, minor=False, fontsize = 20)
ax.set_xlabel('t',fontsize = 20 )
ax.set_yscale('log')
# # ax.set_ylim(1, 1000)
ax.set_ylim(100, 1*pow(10, 4))


ax.plot(index_x,time, color='black',linestyle='dashed', markersize=15, 
         markeredgewidth =1.5, markerfacecolor='none', marker='+')


ax2 = ax.twinx()
ax2.set_ylabel('Speedup Factor', fontsize = 20)
ax2.tick_params(axis='y', which='major', labelsize=20)
ax2.plot(index_x, su, color='black',linestyle='dashed', markersize=15, 
         markeredgewidth =1.5, markerfacecolor='none', marker='>')

# plt.savefig(filename, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1204/4014313165.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels=index_x, minor=False, fontsize = 20)
