# %%
import pandas as pd 
import numpy as np
import os
import math
import matplotlib.pyplot as plt

import os

plt.rcParams['savefig.dpi'] = 300 
plt.rcParams['figure.dpi'] = 300

# %%
path = os.getcwd() + '/figure'
if not os.path.exists(path):
    os.mkdir(path)

def plot_line(a, data,COLOR,LINESTYLE,MAKER,LABEL):
    plt.plot(a,data,color=COLOR,linestyle=LINESTYLE, 
             markersize=15, 
             markeredgewidth =1.5,
             markerfacecolor='none',
             marker=MAKER,label = LABEL)
path = "/mnt/c/Users/lsy/Desktop/graph/"

# %%
data = """RL	215.6751659	18.75456591
YG	65.7026239	12.9887239
GH	94.6823972	10.4040172
TM	1246.488068	84.4522679
IM	137.9093191	25.8538191
WC	16949.9363	402.244297
FG	68791.69062	1709.70062
RA	1252.877613	283.109613
ML	100000	12943.747
DUI	100000	61306.678"""

for line in data.split('\n'):
    ele = line.split('\t')
    print("[\'{}\', {}, {}],".format(ele[0], ele[1], ele[2].replace('\n','')))
# Out:
# ['RL', 215.6751659, 18.75456591],
# ['YG', 65.7026239, 12.9887239],
# ['GH', 94.6823972, 10.4040172],
# ['TM', 1246.488068, 84.4522679],
# ['IM', 137.9093191, 25.8538191],
# ['WC', 16949.9363, 402.244297],
# ['FG', 68791.69062, 1709.70062],
# ['RA', 1252.877613, 283.109613],
# ['ML', 100000, 12943.747],
# ['DUI', 100000, 61306.678],

# %%
# query performence
# default query barplot 
import numpy as np
fig = plt.figure(1, figsize=(6.8*2, 4.0))
ax = fig.add_subplot(111)
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.3

default=[
['RL', 1183.11, 1072.424723, 25.754823],
['YG', 255.415, 139.220662, 13.907962],
['GH', 230.469, 67.21383, 11.05863],
['TM', 18400.6, 17461.46382, 180.706815],
['IM', 2310.24, 1593.20904, 66.16804],
['WC', 41815.9, 35915.00146, 712.76646],
['FG', 0, 0, 1837.0685],
['PA', 82224.2, 78772.7531, 2900.3131],
['ML', 0, 0, 12535.839],
['DUI', 0, 0, 60572.88]
]
default_df=pd.DataFrame(default)
name_list = default_df[0].tolist()
NV= default_df[1].tolist()
TD= default_df[2].tolist()
BU= default_df[3].tolist()

x = np.arange(len(name_list))
# x =list(range(len(our_list)))
total_width, n = 0.9, 3
width = total_width / (n+1)

for i in range(len(x)):
    x[i] = x[i] + width

plt.bar(x, NV, width=width, label="HC-NV",linewidth=1, edgecolor='black',
        fc = 'black')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width, TD, width=width, label="HC-TD",linewidth=0.5,edgecolor='black',hatch="\\\\"*2,
        fc = 'w')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width+width, BU, width=width, label="HC-BU",color="w" ,edgecolor="black")

plt.xticks(x+0.5*width, name_list)

# plt.yscale('log')
plt.yscale('log', subs=[])
plt.ylim(8,1*pow(10,5.2))
# ymajorLocator = MultipleLocator(100) 
# plt.ylim(1, 90000)
plt.ylabel("Time(s)",fontsize = 20)
# plt.yticks([1*pow(10,1), 1*pow(10,2), 1*pow(10,3), 1*pow(10,4), 1*pow(10,5), 1*pow(10,6)], [ '$10^1$', '$10^2$', '$10^3$','$10^4$','$10^5$','$10^6$'])

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Datasets",fontsize=20)

# ax.set_xticks(x+1.5*width)

# plt.legend(fontsize=18,ncol=3,loc= "upper left",bbox_to_anchor=(0, 0.75,0.5,0.5)) 
# plt.legend(fontsize=17,ncol=4,loc="upper left") 
plt.legend(fontsize=16 ,ncol=3,loc="upper left", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1) 
plt.savefig(path + "nindex.pdf", bbox_inches='tight')
plt.show()

# %%
# query performence
# default query barplot 
import numpy as np
fig = plt.figure(1, figsize=(6.8*2, 4.0))
ax = fig.add_subplot(111)
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.3

default=[
['RL', 1.866288, 14.371132],
['YG', 2.34688, 14.907568],
['GH', 3.521896, 26.645588],
['TM', 10.931728, 50.384692],
['IM', 21.724824, 34.1],
['WC', 30.36636, 288.492268],
['FG', 68.362448, 263.065488],
['PA', 98.256472, 475.38806],
['ML', 200.00076, 2746.622212],
['DUI', 814.39164, 1190.1064]
]

default_df=pd.DataFrame(default)
name_list = default_df[0].tolist()
peel_list= default_df[1].tolist()
expand_list= default_df[2].tolist()

x = np.arange(len(name_list))
# x =list(range(len(our_list)))
total_width, n = 0.9, 2
width = total_width / (n+1)

for i in range(len(x)):
    x[i] = x[i] + width

plt.bar(x, peel_list, width=width, label="Graph size", linewidth=1, edgecolor='black',
        fc = 'black')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width, expand_list, width=width, label="Index size",linewidth=0.5,edgecolor='black',hatch="\\\\"*2,
        fc = 'w')

plt.xticks(x+0.5*width, name_list)

# plt.yscale('log')
# plt.yscale('log')
plt.ylim(1, 100000)
plt.ylabel("Index size(MB)",fontsize = 20)
# plt.yticks(pos, labels)
plt.yticks([1, 10, 100, 1000, 8000, 10000, 30000, 60000, 80000, 90000])

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Datasets",fontsize=20)

# ax.set_xticks(x+1.5*width)

# plt.legend(fontsize=18,ncol=3,loc= "upper left",bbox_to_anchor=(0, 0.75,0.5,0.5)) 
# plt.legend(fontsize=17,ncol=4,loc="upper left") 
plt.legend(fontsize=18 ,ncol=2,loc="upper left", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1) 
plt.savefig(path + "index_size.pdf", bbox_inches='tight')
plt.show()

# %%
data="""1.22556
3.9164
9.07341
10.09079
20.09943
38.63913
78.91473
148.50713
316.74713
734.23613"""

result = []
for line in data.split('\n'):
    result.append(line.replace('\n',''))

print(", ".join(str(i) for i in result))
# Out:
# 1.22556, 3.9164, 9.07341, 10.09079, 20.09943, 38.63913, 78.91473, 148.50713, 316.74713, 734.23613

# %%
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
index_x = [ '$2^1$', '$2^2$', '$2^3$','$2^4$','$2^5$','$2^6$','$2^7$','$2^8$','$2^9$']
font2 = {'weight': 'normal', 'size': 18}

# labels = (r"$10^0$",r"$10^1$", r"$10^2$", r"$10^3$",r"$10^4$",r"$10^5$", "INF")

DEL = [11.859183, 29.871283, 63.642383, 421.814883, 1249.260883, 1800.080883, 2814.470883, 4212.640883, 7780.180883]
INS = [13.85088, 17.90318, 38.74928, 89.59218, 179.31668, 349.23868, 688.51768, 1296.48468, 2738.64468]
BU = [2900.3131,2900.3131,2900.3131,2900.3131,2900.3131,2900.3131,2900.3131,2900.3131,2900.3131]

# stackoverflow_peeling =[511052.2,236689.9,92571.3,74803.4,58010.8]
# stackoverflow_expand = [356276,208589.7,161437.2,110580,86341.7]

plot_line(index_x, INS, 'black','dashed', "o", "HM-Ins")
plot_line(index_x, DEL, 'black','dashed', "x", "HM-Del")
plot_line(index_x, BU, 'black','dashed', "+", "HC-BU")
plt.yscale('log')

plt.ylim(1, 1*pow(10,5))
plt.ylabel("Time Cost (sec)",fontsize = 18)
plt.xlabel(r"x",fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(loc='upper left',ncol=3, frameon=False, prop = font2) 
plt.savefig(path + "NPAU.pdf", bbox_inches='tight')

# %%
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
index_x = ['$2^1$', '$2^2$', '$2^3$','$2^4$','$2^5$','$2^6$','$2^7$','$2^8$','$2^9$']
font2 = {'weight': 'normal', 'size': 18}

# labels = (r"$10^0$",r"$10^1$", r"$10^2$", r"$10^3$",r"$10^4$",r"$10^5$", "INF")

DEL = [7.868, 25.69278, 27.46308, 43.12188, 77.82708, 156.20548, 273.74848, 575.50148, 1391.21148]
INS = [3.9164, 9.07341, 10.09079, 20.09943, 38.63913, 78.91473, 148.50713, 316.74713, 734.23613]
BU = [66.16804,66.16804,66.16804,66.16804,66.16804,66.16804,66.16804,66.16804,66.16804]

# stackoverflow_peeling =[511052.2,236689.9,92571.3,74803.4,58010.8]
# stackoverflow_expand = [356276,208589.7,161437.2,110580,86341.7]

plot_line(index_x, INS, 'black','dashed', "o", "HM-Ins")
plot_line(index_x, DEL, 'black','dashed', "x", "HM-Del")
plot_line(index_x, BU, 'black','dashed', "+", "HC-BU")

plt.axvline(x='$2^6$', color='b', label='axvline - full height')

plt.yscale('log')

plt.ylim(1, 1*pow(10,4))
plt.ylabel("Time Cost (sec)",fontsize = 18)
plt.xlabel(r"x",fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(loc='upper left',ncol=3, frameon=False, prop = font2) 
plt.savefig(path + "NIMU.pdf", bbox_inches='tight')

# %%
data="""0.565093
1.038843
2.685223
4.505383
10.401093
24.861993
51.001893
108.788693
225.453693
438.304693"""

result = []
for line in data.split('\n'):
    result.append(line.replace('\n',''))

print(", ".join(str(i) for i in result))
# Out:
# 0.565093, 1.038843, 2.685223, 4.505383, 10.401093, 24.861993, 51.001893, 108.788693, 225.453693, 438.304693

# %%
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
index_x = ['$2^1$', '$2^2$', '$2^3$','$2^4$','$2^5$','$2^6$','$2^7$','$2^8$','$2^9$']
font2 = {'weight': 'normal', 'size': 18}

# labels = (r"$10^0$",r"$10^1$", r"$10^2$", r"$10^3$",r"$10^4$",r"$10^5$", "INF")

DEL = [5.03187, 6.21881, 8.16142, 14.51058, 79.80938, 528.43498, 1344.77498, 2775.37498, 3571.76498]
INS = [ 1.038843, 2.685223, 4.505383, 10.401093, 24.861993, 51.001893, 108.788693, 225.453693, 438.304693]
BU = [712.76646,712.76646,712.76646,712.76646,712.76646,712.76646,712.76646,712.76646,712.76646]

# stackoverflow_peeling =[511052.2,236689.9,92571.3,74803.4,58010.8]
# stackoverflow_expand = [356276,208589.7,161437.2,110580,86341.7]

plot_line(index_x, INS, 'black','dashed', "o", "HM-Ins")
plot_line(index_x, DEL, 'black','dashed', "x", "HM-Del")
plot_line(index_x, BU, 'black','dashed', "+", "HC-BU")
plt.yscale('log')

plt.ylim(1, 1*pow(10,5))
plt.ylabel("Time Cost (sec)",fontsize = 18)
plt.xlabel(r"x",fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(loc='upper left',ncol=3, frameon=False, prop = font2) 
plt.savefig(path + "NWCU.pdf", bbox_inches='tight')

# %%
data="""7.55919
21.03799
133.49099
288.24299
594.49199
1250.52199
2538.14199
5623.78199
10647.16199
21802.66199"""

result = []
for line in data.split('\n'):
    result.append(line.replace('\n',''))

print(", ".join(str(i) for i in result))
# Out:
# 7.55919, 21.03799, 133.49099, 288.24299, 594.49199, 1250.52199, 2538.14199, 5623.78199, 10647.16199, 21802.66199

# %%
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
index_x = ['$2^1$', '$2^2$', '$2^3$','$2^4$','$2^5$','$2^6$','$2^7$','$2^8$','$2^9$']
font2 = {'weight': 'normal', 'size': 18}

# labels = (r"$10^0$",r"$10^1$", r"$10^2$", r"$10^3$",r"$10^4$",r"$10^5$", "INF")

DEL = [43.40967, 104.55557, 211.34597, 457.02897, 771.19497, 1704.46597, 3447.98597, 6980.74597, 14698.89597]
INS = [21.03799, 133.49099, 288.24299, 594.49199, 1250.52199, 2538.14199, 5623.78199, 10647.16199, 21802.66199]
BU = [1837.0685,1837.0685,1837.0685,1837.0685,1837.0685,1837.0685,1837.0685,1837.0685,1837.0685]

# stackoverflow_peeling =[511052.2,236689.9,92571.3,74803.4,58010.8]
# stackoverflow_expand = [356276,208589.7,161437.2,110580,86341.7]

plot_line(index_x, INS, 'black','dashed', "o", "HM-Ins")
plot_line(index_x, DEL, 'black','dashed', "x", "HM-Del")
plot_line(index_x, BU, 'black','dashed', "+", "HC-BU")
plt.yscale('log')

plt.ylim(1, 1*pow(10,6))
plt.ylabel("Time Cost (sec)",fontsize = 18)
plt.xlabel(r"x",fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(loc='upper left',ncol=3, frameon=False, prop = font2) 
plt.savefig(path + "NFGU.pdf", bbox_inches='tight')

# %%
data="""4.61276	0.144901	62.5798	0.367805	47.5137	18.0285	0.039391	0.525457	352.633
0.112727	0.0535009	0.305709	0.0133265	0.986075	1.08778	0.00862514	0.0111979	6.9424
1.73506	0.101874	9.45447	0.105747	19.1796	10.2358	0.0211181	0.179227	127.031
2.4499	0.146706	0.636842	0.205289	12.3353	13.8081	0.038809	0.334109	169.916
0.0305554	0.0184196	0.243928	0.00862806	0.50243	0.606891	0.00935241	0.0151168	7.31042
0.911107	0.044571	0.488347	0.0636646	4.03538	6.56729	0.0210162	0.118511	46.9367"""

# %%
lines = data.split('\n')

values = []

for line in lines:
    line = line.split('\t')
    temp = []
    temp.append(line[6])
    temp.append(line[3])
    temp.append(line[7])
    temp.append(line[1])
    temp.append(line[0])
    temp.append(line[2])
    temp.append(line[5])
    temp.append(line[4])
    temp.append(line[8])
    values.append(temp)

# %%
# 0 max del
# 1 min del
# 2 avg del
# 3 max Ins
# 4 Min ins
# 5 avg ins
ins = []
dels = []
for i in range(len(values[0])):
    ins.apeend([np.subtract()])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_22769/189157787.py in <module>
#       8 dels = []
#       9 for i in range(len(values[0])):
# ---> 10     ins.apeend([np.subtract()])
#
# AttributeError: 'list' object has no attribute 'apeend'

# %%
# query performence
# default query barplot 
import numpy as np
fig = plt.figure(1, figsize=(6.8*2, 4.0))
ax = fig.add_subplot(111)
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.3
# 0.7
# default=[
# ['BS',0.029819,0.051474],
# ['GH',0.026776,0.039266],
# ['SO',0.039862,0.06904],
# ['LS',0.353383,0.241707],
# ['DT',0.095762,0.18853],
# ['AR',0.144527,0.351827],
# ['PA',0.012013,0.17036],
# ['ML',2.35578,2.7036],
# ['DUI',7.902685,10.010397],
# ['EN',1.872024,2.798319],
# ['DTI',1.101762,2.186652],
# ]
default=[
['RL', 18.75456591, 0.0210162, 0.0211181],
['YG', 12.9887239, 0.0636646, 0.105747],
['GH', 10.4040172, 0.118511, 0.179227],
['TM', 84.4522679, 0.044571, 0.101874],
['IM', 25.8538191, 0.911107, 1.73506],
['WC', 402.244297, 0.488347, 9.45447],
['FG', 1709.70062, 6.56729, 10.2358],
['PA', 283.109613, 4.03538, 19.1796],
['ML', 12943.747, 46.9367, 127.031],
['DUI', 61306.678, 574.985, 1298.11]
]

default_df=pd.DataFrame(default)
name_list = default_df[0].tolist()
peel_list= default_df[1].tolist()
expand_list= default_df[2].tolist()
avglist = default_df[3].tolist()

x = np.arange(len(name_list))
# x =list(range(len(our_list)))
total_width, n = 0.9, 3
width = total_width / (n+1)

for i in range(len(x)):
    x[i] = x[i] + width

plt.bar(x, peel_list, width=width, label="HC-BU",linewidth=1, edgecolor='black',
        fc = 'black')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width, expand_list, width=width, label="HM-Ins",linewidth=0.5,edgecolor='black',hatch="\\\\"*2,
        fc = 'w')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width + width, avglist, width=width, label="HM-Del",linewidth=0.5,edgecolor='black',fc = 'w')

plt.xticks(x+0.5*width,name_list)

plt.yscale('log')
plt.yscale('log')
plt.ylim(0.01,1*pow(10,6))
plt.ylabel("Time(s)",fontsize = 20)
# plt.yticks(pos, labels)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Datasets",fontsize=20)

# ax.set_xticks(x+1.5*width)

# plt.legend(fontsize=18,ncol=3,loc= "upper left",bbox_to_anchor=(0, 0.75,0.5,0.5)) 
# plt.legend(fontsize=17,ncol=4,loc="upper left") 
plt.legend(fontsize=18 ,ncol=3,loc="upper left", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1) 
plt.savefig(path + "update.pdf", bbox_inches='tight')
plt.show()

# %%
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
index_x = ['0.1', '0.3', '0.5', '0.7','0.9']
font2 = {'weight': 'normal', 'size': 20}

# labels = (r"$10^0$",r"$10^1$", r"$10^2$", r"$10^3$",r"$10^4$",r"$10^5$", "INF")

dfbu = [0.00153774, 9.6305e-05, 4.317e-06, 3.317e-06, 4.43e-06]
dfab = [0.0974132, 0.00199887,0.000215286, 0.000235252, 0.000242798]
dfpe = [0.619932, 0.469546, 0.441063, 0.443568, 0.427733]


# stackoverflow_peeling =[511052.2,236689.9,92571.3,74803.4,58010.8]
# stackoverflow_expand = [356276,208589.7,161437.2,110580,86341.7]

plot_line(index_x, dfpe, 'black','dashed', "+", r"$Q_{o}$")
plot_line(index_x, dfab, 'black','dashed', "x", r"$Q_{v}$")
plot_line(index_x, dfbu, 'black','dashed', "o", r"$Q_{h}$")

plt.yscale('log')

plt.ylim(0.000001, 1*pow(10,2))
plt.ylabel("Time Cost (sec)",fontsize = 20)
plt.xlabel(r"c",fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(loc='upper left',ncol=3, frameon=False, prop = font2) 
plt.savefig(path + "query_dblp_fix_b.pdf", bbox_inches='tight')

# %%
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
index_x = ['0.1', '0.3', '0.5', '0.7','0.9']
font2 = {'weight': 'normal', 'size': 20}

# labels = (r"$10^0$",r"$10^1$", r"$10^2$", r"$10^3$",r"$10^4$",r"$10^5$", "INF")

dfbu = [0.0083651, 0.000592031, 2.283e-06, 2.993e-06, 4.039e-06]
dfab = [0.840018, 0.0686353, 0.000213343, 0.000228571, 0.000237543]
dfpe = [1.1526, 0.613883, 0.441644, 0.429086, 0.423525]


# stackoverflow_peeling =[511052.2,236689.9,92571.3,74803.4,58010.8]
# stackoverflow_expand = [356276,208589.7,161437.2,110580,86341.7]

plot_line(index_x, dfpe, 'black','dashed', "+", r"$Q_{o}$")
plot_line(index_x, dfab, 'black','dashed', "x", r"$Q_{v}$")
plot_line(index_x, dfbu, 'black','dashed', "o", r"$Q_{h}$")
plt.yscale('log')

plt.ylim(0.000001, 1*pow(10,2))
plt.ylabel("Time Cost (sec)",fontsize = 20)
plt.xlabel(r"c",fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(loc='upper left',ncol=3, frameon=False, prop = font2) 
plt.savefig(path + "query_dblp_fix_a.pdf", bbox_inches='tight')

# %%
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
index_x = ['0.1', '0.3', '0.5', '0.7','0.9']
font2 = {'weight': 'normal', 'size': 20}

# labels = (r"$10^0$",r"$10^1$", r"$10^2$", r"$10^3$",r"$10^4$",r"$10^5$", "INF")

dfbu = [2.9996e-05, 1.5126e-05, 1.1543e-05, 9.274e-06, 8.785e-06]
dfab = [0.00261109, 0.00150286, 0.00124974, 0.00113609, 0.00103769]
dfpe = [0.00759296, 0.00682473, 0.00664261, 0.00652652, 0.0064638]


# stackoverflow_peeling =[511052.2,236689.9,92571.3,74803.4,58010.8]
# stackoverflow_expand = [356276,208589.7,161437.2,110580,86341.7]

plot_line(index_x, dfpe, 'black','dashed', "+", r"$Q_{o}$")
plot_line(index_x, dfab, 'black','dashed', "x", r"$Q_{v}$")
plot_line(index_x, dfbu, 'black','dashed', "o", r"$Q_{h}$")
plt.yscale('log')

plt.ylim(0.000001, 1*pow(10,0))
plt.ylabel("Time Cost (sec)",fontsize = 20)
plt.xlabel(r"c",fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(loc='upper left',ncol=3, frameon=False, prop = font2) 
plt.savefig(path + "query_github_a.pdf", bbox_inches='tight')

# %%
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.5
index_x = ['0.1', '0.3', '0.5', '0.7','0.9']
font2 = {'weight': 'normal', 'size': 20}

# labels = (r"$10^0$",r"$10^1$", r"$10^2$", r"$10^3$",r"$10^4$",r"$10^5$", "INF")

dfbu = [3.1884e-05, 1.6717e-05, 1.1818e-05, 8.637e-06, 6.599e-06]
dfab = [0.00201998, 0.00148394, 0.00124903, 0.00112966, 0.00100271]
dfpe = [0.00667391, 0.00671525, 0.00664684, 0.0065134, 0.00637542]


# stackoverflow_peeling =[511052.2,236689.9,92571.3,74803.4,58010.8]
# stackoverflow_expand = [356276,208589.7,161437.2,110580,86341.7]

plot_line(index_x, dfpe, 'black','dashed', "+", r"$Q_{o}$")
plot_line(index_x, dfab, 'black','dashed', "x", r"$Q_{v}$")
plot_line(index_x, dfbu, 'black','dashed', "o", r"$Q_{h}$")
plt.yscale('log')

plt.ylim(0.000001, 1*pow(10,0))
plt.ylabel("Time Cost (sec)",fontsize = 20)
plt.xlabel(r"c",fontsize = 20)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.legend(loc='upper left',ncol=3, frameon=False, prop = font2) 
plt.savefig(path + "query_github_b.pdf", bbox_inches='tight')

# %%
# query performence
# default query barplot 
import numpy as np
fig = plt.figure(1, figsize=(6.8*2, 4.0))
ax = fig.add_subplot(111)
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.3
# 0.7
# default=[
# ['BS',0.029819,0.051474],
# ['GH',0.026776,0.039266],
# ['SO',0.039862,0.06904],
# ['LS',0.353383,0.241707],
# ['DT',0.095762,0.18853],
# ['AR',0.144527,0.351827],
# ['PA',0.012013,0.17036],
# ['ML',2.35578,2.7036],
# ['DUI',7.902685,10.010397],
# ['EN',1.872024,2.798319],
# ['DTI',1.101762,2.186652],
# ]
default=[
['RL', 2.1159100000000005e-05,0.0011634249999999998,0.004192937],
['YG', 1.13318e-05,0.001080244,0.0045819070000000005],
['GH', 1.24275e-05,0.001248153,0.0066310580000000004],
['TM', 0.00014446820000000001,0.010969930000000001,0.028594830000000005],
['IM', 0.0001046553,0.013209790000000003,0.0730903],
['WC', 4.24373e-05,0.0028098539,0.09010356],
['FG', 0.0001469142,0.040441519999999995,0.08238537],
['PA', 5.378100000000001e-06,0.00022161330000000003,0.4411156],
['ML', 0.0002158049,0.11641839999999999,0.16096030000000003],
['DUI', 0.0007089592999999999,0.6057245,4.4308309999999995]
]
default_df=pd.DataFrame(default)
name_list = default_df[0].tolist()
dfbu = default_df[1].tolist()
dfab = default_df[2].tolist()
dfpe = default_df[3].tolist()

x = np.arange(len(name_list))
# x =list(range(len(our_list)))
total_width, n = 0.9, 4
width = total_width / (n+1)

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, dfpe, width=width, label=r"$Q_{o}$",linewidth=1,edgecolor='black',
        fc = 'black')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width, dfab, width=width, label=r"$Q_{v}$",linewidth=0.5,edgecolor='black',hatch="\\\\"*2,
        fc = 'w')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width+width, dfbu, width=width, label=r"$Q_{h}$",linewidth=0.5,color="w" ,edgecolor="black")

plt.xticks(x+1*width, name_list,rotation=0)

plt.yscale('log')
plt.yscale('log')
plt.ylim(0.000001,1*pow(10,1))
plt.ylabel("Time Cost (sec)",fontsize = 20)
# plt.yticks(pos, labels)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Datasets",fontsize=20)

# ax.set_xticks(x+1.5*width)

# plt.legend(fontsize=18,ncol=3,loc= "upper left",bbox_to_anchor=(0, 0.75,0.5,0.5)) 
# plt.legend(fontsize=17,ncol=4,loc="upper left") 
plt.legend(fontsize=18 ,ncol=3,loc="upper left", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1) 
plt.savefig(path + "query_performance_time.pdf", bbox_inches='tight')
plt.show()

# %%
hmdel = pd.read_csv("/mnt/c/Users/lsy/Desktop/graph/del.csv")
hmins = pd.read_csv("/mnt/c/Users/lsy/Desktop/graph/ins.csv")
hmins
# Out:
#          RL        YG        GH        TM        IM        WC        FG  \
# 0  0.024419  0.104337  0.178163  0.086010  0.313023  0.246543  5.834630
# 1  0.010182  0.009547  0.078545  0.088079  3.687360  0.508617  9.400400
# 2  0.016217  0.009659  0.227439  0.087952  0.182744  0.523978  9.075650
# 3  0.015228  0.018880  0.122114  0.071349  3.724120  0.504248  0.372473
# 4  0.009777  0.105836  0.291539  0.079221  0.193551  0.633458  9.212690
# 5  0.010804  0.010958  0.091202  0.079400  0.277658  0.323907  0.489084
# 6  0.030624  0.027075  0.185110  0.079694  1.140520  0.628640  1.733240
# 7  0.014409  0.039959  0.054806  0.085149  0.616181  0.481915  9.702580
# 8  0.022649  0.018665  0.019168  0.150069  0.919545  0.625936  1.090950
# 9  0.011245  0.105295  0.017052  0.081514  2.076710  0.358904  0.880535
#
#          PA         ML         DUI
# 0  10.33370    9.35680     7.72610
# 1   2.13561   17.73340  1343.27000
# 2   1.44685  178.41700    36.62340
# ...

# %%
# query performence
# default query barplot 
import numpy as np
fig = plt.figure(1, figsize=(6.8*2, 4.0))
ax = fig.add_subplot(111)
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.3
# 0.7
# default=[
# ['BS',0.029819,0.051474],
# ['GH',0.026776,0.039266],
# ['SO',0.039862,0.06904],
# ['LS',0.353383,0.241707],
# ['DT',0.095762,0.18853],
# ['AR',0.144527,0.351827],
# ['PA',0.012013,0.17036],
# ['ML',2.35578,2.7036],
# ['DUI',7.902685,10.010397],
# ['EN',1.872024,2.798319],
# ['DTI',1.101762,2.186652],
# ]
default=[
['RL', 18.75456591],
['YG', 12.9887239],
['GH', 10.4040172],
['TM', 84.4522679],
['IM', 25.8538191],
['WC', 402.244297],
['FG', 1709.70062],
['PA', 283.109613],
['ML', 12943.747],
['DUI', 61306.678]
]

default_df=pd.DataFrame(default)
name_list = default_df[0].tolist()
peel_list= default_df[1].tolist()
# expand_list= default_df[2].tolist()
# avglist = default_df[3].tolist()

x = np.arange(len(name_list))
# x =list(range(len(our_list)))
total_width, n = 0.9, 3
width = total_width / (n+1)

for i in range(len(x)):
    x[i] = x[i] + width

plt.bar(x, peel_list, width=width,linewidth=1,edgecolor='black',hatch="\\\\"*2,
        fc = 'w')

for i in range(len(x)):
#     print(x + width)
    x[i] = x[i] + width
    plt.boxplot(hmins[name_list[i]].tolist(), positions=[x[i] + width], showfliers=True,showcaps=True, widths=0.18, whiskerprops={"linewidth": 1})
    plt.plot([x[i] + width, x[i] + width ], [0, hmins[name_list[i]].min()], ':', color="black")
#     plt.plot([x[i] + width * 0.5, x[i] + width * 0.5], [0, hmins[name_list[i]].min()], ':', color="black")

    
for i in range(len(x)):
    x[i] = x[i] + width
    plt.boxplot(hmdel[name_list[i]].tolist(), positions=[x[i] + width + width], showfliers=True,widths=0.18, whiskerprops={"linewidth": 1})
    plt.plot([x[i] + width + width, x[i] + width + width ], [0,hmdel[name_list[i]].min()], ':', color="black")
    
plt.xticks(x+0.5*width, name_list)

plt.yscale('log')
plt.yscale('log')
plt.ylim(0.001, 1*pow(10,6))
plt.ylabel("Time(s)",fontsize = 20)
# plt.yticks(pos, labels)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Datasets",fontsize=20)

# ax.set_xticks(x+1.5*width)

labels = []
# plt.legend(fontsize=18,ncol=3,loc= "upper left",bbox_to_anchor=(0, 0.75,0.5,0.5)) 
# plt.legend(fontsize=17,ncol=4,loc="upper left") 
ax.set_aspect(0.3)
plt.legend(fontsize=20 ,ncol=3,loc="upper left", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1, title='HM-BU, HM-Ins, HM-Del (from left to right)', title_fontsize = 18) 
plt.savefig(path + "update.pdf", bbox_inches='tight')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
query = pd.read_csv('/mnt/c/Users/lsy/Desktop/graph/academic-graph/query.csv')
# Out:
#       BU_RL     AB_RL  Peeling_RL     BU_YG     AB_YG  Peeling_YG     BU_GH  \
# 0  0.000034  0.001164    0.004245  0.000018  0.001081    0.004567  0.000020
# 1  0.000020  0.001163    0.004183  0.000010  0.001086    0.004594  0.000012
# 2  0.000019  0.001160    0.004183  0.000011  0.001073    0.004578  0.000012
# 3  0.000020  0.001162    0.004186  0.000012  0.001078    0.004582  0.000011
# 4  0.000020  0.001168    0.004186  0.000010  0.001078    0.004577  0.000012
# 5  0.000019  0.001161    0.004182  0.000011  0.001076    0.004573  0.000011
# 6  0.000020  0.001162    0.004204  0.000010  0.001087    0.004585  0.000011
# 7  0.000019  0.001160    0.004189  0.000010  0.001082    0.004588  0.000012
# 8  0.000020  0.001166    0.004188  0.000010  0.001084    0.004583  0.000012
# 9  0.000020  0.001167    0.004184  0.000011  0.001078    0.004591  0.000011
#
#       AB_GH  Peeling_GH     BU_TM  ...  Peeling_FG     BU_PA     AB_PA  \
# ...

# %%
# query performence
# default query barplot 
import numpy as np
fig = plt.figure(1, figsize=(6.8*2, 4.0))
ax = fig.add_subplot(111)
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams["legend.framealpha"] = 0
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["legend.handletextpad"] = 0.1
plt.rcParams["legend.columnspacing"] = 0.3
# 0.7
# default=[
# ['BS',0.029819,0.051474],
# ['GH',0.026776,0.039266],
# ['SO',0.039862,0.06904],
# ['LS',0.353383,0.241707],
# ['DT',0.095762,0.18853],
# ['AR',0.144527,0.351827],
# ['PA',0.012013,0.17036],
# ['ML',2.35578,2.7036],
# ['DUI',7.902685,10.010397],
# ['EN',1.872024,2.798319],
# ['DTI',1.101762,2.186652],
# ]
default=[
['RL', 18.75456591,0.0103454, 0.0160188],
['YG', 12.9887239,0.0485327, 0.0397262],
['GH', 10.4040172,0.245132, 0.180002],
['TM', 84.4522679,0.373531, 0.139299],
['IM', 25.8538191,1.222316, 0.933469],
['WC', 402.244297,2.93952, 0.503667],
['FG', 1709.70062,14.4976, 6.39029],
['PA', 283.109613,9.02485, 4.65206],
['ML', 12943.747, 107.02, 47.6342],
['DUI', 61306.678, 774.5729246, 457.09486]
]
default_df=pd.DataFrame(default)
name_list = default_df[0].tolist()
dfbu = default_df[1].tolist()
hmdel = default_df[2].tolist()
hmins = default_df[3].tolist()

x = np.arange(len(name_list))
# x =list(range(len(our_list)))
total_width, n = 0.9, 4
width = total_width / (n+1)

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, dfbu, width=width, label=r"HM-BU",linewidth=1,edgecolor='black',
        fc = 'black')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width, hmins, width=width, label=r"HM-Ins",linewidth=0.5,edgecolor='black',hatch="\\\\"*2,
        fc = 'w')

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x+width+width, hmdel, width=width, label=r"HM-Del",linewidth=0.5,color="w" ,edgecolor="black")

plt.xticks(x+1*width, name_list,rotation=0)

plt.yscale('log')
plt.yscale('log')
plt.ylim(0.001,1*pow(10,6))
plt.ylabel("Time Cost (sec)",fontsize = 20)
# plt.yticks(pos, labels)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Datasets",fontsize=20)

# ax.set_xticks(x+1.5*width)

# plt.legend(fontsize=18,ncol=3,loc= "upper left",bbox_to_anchor=(0, 0.75,0.5,0.5)) 
# plt.legend(fontsize=17,ncol=4,loc="upper left") 
plt.legend(fontsize=18 ,ncol=3,loc="upper left", handlelength = 1.8, handletextpad = 0.4, labelspacing = 0, columnspacing=1) 
plt.savefig(path + "update.pdf", bbox_inches='tight')
plt.show()

# %%
data="""Insert update time: 57.4868
Insert update time: 1392.26
Insert update time: 174.186
Insert update time: 98.4594
Insert update time: 1374.55
Insert update time: 323.838
Insert update time: 7.64633
Insert update time: 266.074
Insert update time: 156.31
Insert update time: 18.177
Insert update time: 7.00264
Insert update time: 80.1749
Insert update time: 180.142
Insert update time: 1356.76
Insert update time: 7.19335
Insert update time: 7.23172
Insert update time: 7.13172
Insert update time: 294.23
Insert update time: 568.698
Insert update time: 100.412
Insert update time: 230.05
Insert update time: 82.243
Insert update time: 6.92934
Insert update time: 282.867
Insert update time: 1006.83
Insert update time: 88.087
Insert update time: 20.251
Insert update time: 1102.8
Insert update time: 6.8277
Insert update time: 362.14
Insert update time: 1659.89
Insert update time: 1168.42
Insert update time: 1574.35
Insert update time: 1837.43
Insert update time: 91.2412"""

temp = data.split('\n')
nums = []

for line in temp:
    line = line.split(': ')
    num = float(line[1].replace('\n', ''))
    nums.append(num)

print(max(nums))
print(min(nums))
print(sum(nums)/len(nums))
# Out:
# 1837.43
# 6.8277
# 457.09486
