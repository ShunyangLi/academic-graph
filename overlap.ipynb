# %%
import pandas as pd 
import numpy as np
import os
import math
import matplotlib.pyplot as plt

import os

plt.rcParams['savefig.dpi'] = 300 
plt.rcParams['figure.dpi'] = 300

path = "/Users/lsy/Desktop/Project/academic-graph/figure/"

# %%
plt.rcParams['figure.figsize'] = (6.4, 4.8)
fig,ax=plt.subplots()

labels = ["1", "8", "16","24", "32"]

x =list(range(len(labels)))
total_width, n = 0.8,2
width = total_width / n

# zero=[0,0,0,0]
# P_scan=[82.93,82.42,77.37,70.55]
# P_bloom = [16.34,15.42,19.15,24.45]
# P_edge = [0.33,1.38,2.28,3.38]
# IC = [0.40,0.77,1.21,1.63]

# b1 = [P_scan[i]+P_bloom[i]+P_edge[i]+IC[i] for i in range(0,4)]
# b2 = [P_bloom[i]+P_edge[i]+IC[i] for i in range(0,4)]
# b3 = [P_edge[i]+IC[i] for i in range(0,4)]
# b4 = IC

# P_scan_PC=[53.22,41.24,33.35,28.06]
# P_bloom_PC = [22.46,24.82,25.12,26.49]
# p_edge_PC = [2.43,7.54,9.66,11.09]
# IC_PC = [21.89,26.40,31.87,34.37]

# b11 = [P_scan_PC[i]+P_bloom_PC[i]+p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b22 = [P_bloom_PC[i]+p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b33 = [p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b44 = IC_PC

GC=[123.574,21.423,12.685,10.087,9.290]
count=[133.859,27.771,17.773,15.067,14.256]

IG_BS_GC=[43.768,9.380,5.972,4.227,4.009]
IG_ADV_count=[50.857,13.836,10.442,9.689,8.900]

bar1 = plt.bar([i - 0.2 for i in x], count , width = width ,label = "GC" , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black") 

bar2 = plt.bar([i + 0.2for i in x], IG_ADV_count , width = width, label = "IG-BS"  , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black")


bar22 = plt.bar([i + 0.2for i in x],IG_BS_GC , width = width, label = "IG-ADV" , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black",hatch="\\\\"*2)


bar11 = plt.bar([i - 0.2 for i in x],GC , width = width ,label = "count"  , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black",hatch="//"*2) 



my_y_ticks = np.arange(0, 250,50)
plt.yticks(my_y_ticks)
# plt.yscale('log')
# plt.ylim(1,2*pow(10,6))

plt.xticks(fontsize=20) #rotation=-15,
plt.yticks(fontsize=20)
plt.ylabel('Time Cost (sec)',fontsize=20)
plt.xlabel('t',fontsize=20)
# ,handlelength = 1.6, handletextpad = 0.4, labelspacing = 0, columnspacing=0.4,
#            bbox_to_anchor=(2, 1.2)
legend = ax.legend((bar1,bar11, bar2, bar22, ),
                   ("IG-BS-GC","IG-BS-Count","IG-ADV-GC","IG-ADV-Count"),
                   loc='upper right',fontsize=16 ,ncol=2,frameon = 0,
                   handlelength = 1.6, handletextpad = 0.4, labelspacing = 0.2, columnspacing=0.5,bbox_to_anchor=(1, 1) )
# frame = legend.get_frame()
# frame.set_alpha(1) 
# frame.set_facecolor('w')
# frame.set_edgecolor('black')
# legend.get_frame().set_facecolor('C0')
plt.xticks(x,labels)
ax.tick_params(axis="x",direction="in", left="off",labelleft="on")
plt.savefig(path+"tdelicious.pdf", bbox_inches = 'tight')

# %%
fig,ax=plt.subplots()

labels = ["1", "8", "16","24", "32"]

x =list(range(len(labels)))
total_width, n = 0.8,2
width = total_width / n

# zero=[0,0,0,0]
# P_scan=[82.93,82.42,77.37,70.55]
# P_bloom = [16.34,15.42,19.15,24.45]
# P_edge = [0.33,1.38,2.28,3.38]
# IC = [0.40,0.77,1.21,1.63]

# b1 = [P_scan[i]+P_bloom[i]+P_edge[i]+IC[i] for i in range(0,4)]
# b2 = [P_bloom[i]+P_edge[i]+IC[i] for i in range(0,4)]
# b3 = [P_edge[i]+IC[i] for i in range(0,4)]
# b4 = IC

# P_scan_PC=[53.22,41.24,33.35,28.06]
# P_bloom_PC = [22.46,24.82,25.12,26.49]
# p_edge_PC = [2.43,7.54,9.66,11.09]
# IC_PC = [21.89,26.40,31.87,34.37]

# b11 = [P_scan_PC[i]+P_bloom_PC[i]+p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b22 = [P_bloom_PC[i]+p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b33 = [p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b44 = IC_PC

GC=[59.377,11.388,6.570,4.971,4.636]
count=[70.225,17.405,12.433,10.558,9.193]

IG_BS_GC=[27.453,6.112,3.296,2.686,2.526]
IG_ADV_count=[35.802,11.247,7.846,7.355,6.971]

bar1 = plt.bar([i - 0.2 for i in x], count , width = width ,label = "GC" , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black") 

bar2 = plt.bar([i + 0.2for i in x], IG_ADV_count , width = width, label = "IG-BS"  , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black")


bar22 = plt.bar([i + 0.2for i in x],IG_BS_GC , width = width, label = "IG-ADV" , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black",hatch="\\")


bar11 = plt.bar([i - 0.2 for i in x],GC , width = width ,label = "count"  , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black",hatch="/") 







my_y_ticks = np.arange(0, 100, 40)
plt.yticks(my_y_ticks)
# plt.yscale('log')
# plt.ylim(1,2*pow(10,6))

plt.xticks( fontsize=20) #rotation=-15,
plt.yticks(fontsize=20)
plt.ylabel('Time Cost (sec)',fontsize=20)
# plt.xlabel('trackers',fontsize=20)
# ,handlelength = 1.6, handletextpad = 0.4, labelspacing = 0, columnspacing=0.4,
#            bbox_to_anchor=(2, 1.2)
legend = ax.legend((bar1,bar11, bar2, bar22, ),
                   ("GC","count","IG-BS","IG-ADV"),
                   loc='upper right',fontsize=16 ,ncol=2,frameon = 0,
                   handlelength = 1.6, handletextpad = 0.4, labelspacing = 0.2, columnspacing=0.5,bbox_to_anchor=(1, 1) )
# frame = legend.get_frame()
# frame.set_alpha(1) 
# frame.set_facecolor('w')
# frame.set_edgecolor('black')
# legend.get_frame().set_facecolor('C0')
plt.xticks(x,labels)
ax.tick_params(axis="x",direction="in", left="off",labelleft="on")
plt.savefig(path+"btrackers.pdf", bbox_inches = 'tight')

# %%
fig,ax=plt.subplots()

labels = ["1", "8", "16","24", "32"]

x =list(range(len(labels)))
total_width, n = 0.8,2
width = total_width / n

# zero=[0,0,0,0]
# P_scan=[82.93,82.42,77.37,70.55]
# P_bloom = [16.34,15.42,19.15,24.45]
# P_edge = [0.33,1.38,2.28,3.38]
# IC = [0.40,0.77,1.21,1.63]

# b1 = [P_scan[i]+P_bloom[i]+P_edge[i]+IC[i] for i in range(0,4)]
# b2 = [P_bloom[i]+P_edge[i]+IC[i] for i in range(0,4)]
# b3 = [P_edge[i]+IC[i] for i in range(0,4)]
# b4 = IC

# P_scan_PC=[53.22,41.24,33.35,28.06]
# P_bloom_PC = [22.46,24.82,25.12,26.49]
# p_edge_PC = [2.43,7.54,9.66,11.09]
# IC_PC = [21.89,26.40,31.87,34.37]

# b11 = [P_scan_PC[i]+P_bloom_PC[i]+p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b22 = [P_bloom_PC[i]+p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b33 = [p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b44 = IC_PC

GC=[674.497,103.950,57.928,41.651,30.433]
count=[689.298,117.164,68.685,51.334,39.252]

IG_BS_GC=[275.031,52.967,26.426,19.175,17.075]
IG_ADV_count=[287.406,64.080,35.651,28.827,24.792]

bar1 = plt.bar([i - 0.2 for i in x], count , width = width ,label = "GC" , linewidth=1.5,
               fc = '#fff3b0',edgecolor="black") 

bar2 = plt.bar([i + 0.2for i in x], IG_ADV_count , width = width, label = "IG-BS"  , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black")


bar22 = plt.bar([i + 0.2for i in x],IG_BS_GC , width = width, label = "IG-ADV" , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black",hatch="\\\\"*2)


bar11 = plt.bar([i - 0.2 for i in x],GC , width = width ,label = "count"  , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black",hatch="//"*2) 







my_y_ticks = np.arange(0, 900,200)
plt.yticks(my_y_ticks)
# plt.yscale('log')
# plt.ylim(1,2*pow(10,6))

plt.xticks( fontsize=20) #rotation=-15,
plt.yticks(fontsize=20)
plt.ylabel('Time Cost (sec)',fontsize=20)
# plt.xlabel('orkut',fontsize=20)
# ,handlelength = 1.6, handletextpad = 0.4, labelspacing = 0, columnspacing=0.4,
#            bbox_to_anchor=(2, 1.2)
legend = ax.legend((bar1,bar11, bar2, bar22, ),
                   ("GC","count","IG-BS","IG-ADV"),
                   loc='upper right',fontsize=16 ,ncol=2,frameon = 0,
                   handlelength = 1.6, handletextpad = 0.4, labelspacing = 0.2, columnspacing=0.5,bbox_to_anchor=(1, 1) )
# frame = legend.get_frame()
# frame.set_alpha(1) 
# frame.set_facecolor('w')
# frame.set_edgecolor('black')
# legend.get_frame().set_facecolor('C0')
plt.xticks(x,labels)
ax.tick_params(axis="x",direction="in", left="off",labelleft="on")
plt.savefig(path+"borkut.pdf", bbox_inches = 'tight')
# Out:
#   File "<ipython-input-3-fc345e2a85e2>", line 48
#     fc = '#fff3b0' ,edgecolor="black"hatch="//"*2)
#                                          ^
# SyntaxError: invalid syntax

# %%
fig,ax=plt.subplots()

labels = ["1", "8", "16","24", "32"]

x =list(range(len(labels)))
total_width, n = 0.8,2
width = total_width / n

# zero=[0,0,0,0]
# P_scan=[82.93,82.42,77.37,70.55]
# P_bloom = [16.34,15.42,19.15,24.45]
# P_edge = [0.33,1.38,2.28,3.38]
# IC = [0.40,0.77,1.21,1.63]

# b1 = [P_scan[i]+P_bloom[i]+P_edge[i]+IC[i] for i in range(0,4)]
# b2 = [P_bloom[i]+P_edge[i]+IC[i] for i in range(0,4)]
# b3 = [P_edge[i]+IC[i] for i in range(0,4)]
# b4 = IC

# P_scan_PC=[53.22,41.24,33.35,28.06]
# P_bloom_PC = [22.46,24.82,25.12,26.49]
# p_edge_PC = [2.43,7.54,9.66,11.09]
# IC_PC = [21.89,26.40,31.87,34.37]

# b11 = [P_scan_PC[i]+P_bloom_PC[i]+p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b22 = [P_bloom_PC[i]+p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b33 = [p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b44 = IC_PC

GC=[1155.037,194.305,101.997,72.903,57.543]
count=[1192.242,222.578,130.299,96.161,81.784]

IG_BS_GC=[475.725,91.663,47.595,33.513,27.950]
IG_ADV_count=[506.659,114.986,71.635,56.369,48.899]

bar1 = plt.bar([i - 0.2 for i in x], count , width = width ,label = "GC" , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black") 

bar2 = plt.bar([i + 0.2for i in x], IG_ADV_count , width = width, label = "IG-BS"  , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black")


bar22 = plt.bar([i + 0.2for i in x],IG_BS_GC , width = width, label = "IG-ADV" , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black",hatch="\\")


bar11 = plt.bar([i - 0.2 for i in x],GC , width = width ,label = "count"  , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black",hatch="/") 







my_y_ticks = np.arange(0, 1500, 300)
plt.yticks(my_y_ticks)
# plt.yscale('log')
# plt.ylim(1,2*pow(10,6))

plt.xticks( fontsize=20) #rotation=-15,
plt.yticks(fontsize=20)
plt.ylabel('Time Cost (sec)',fontsize=20)
# plt.xlabel('bi-twitter',fontsize=20)
# ,handlelength = 1.6, handletextpad = 0.4, labelspacing = 0, columnspacing=0.4,
#            bbox_to_anchor=(2, 1.2)
legend = ax.legend((bar1,bar11, bar2, bar22, ),
                   ("GC","count","IG-BS","IG-ADV"),
                   loc='upper right',fontsize=16 ,ncol=2,frameon = 0,
                   handlelength = 1.6, handletextpad = 0.4, labelspacing = 0.2, columnspacing=0.5,bbox_to_anchor=(1, 1) )
# frame = legend.get_frame()
# frame.set_alpha(1) 
# frame.set_facecolor('w')
# frame.set_edgecolor('black')
# legend.get_frame().set_facecolor('C0')
plt.xticks(x,labels)
ax.tick_params(axis="x",direction="in", left="off",labelleft="on")
plt.savefig(path+"bbi-twitter.pdf", bbox_inches = 'tight')

# %%
fig,ax=plt.subplots()

labels = ["1", "8", "16","24", "32"]

x =list(range(len(labels)))
total_width, n = 0.8,2
width = total_width / n

# zero=[0,0,0,0]
# P_scan=[82.93,82.42,77.37,70.55]
# P_bloom = [16.34,15.42,19.15,24.45]
# P_edge = [0.33,1.38,2.28,3.38]
# IC = [0.40,0.77,1.21,1.63]

# b1 = [P_scan[i]+P_bloom[i]+P_edge[i]+IC[i] for i in range(0,4)]
# b2 = [P_bloom[i]+P_edge[i]+IC[i] for i in range(0,4)]
# b3 = [P_edge[i]+IC[i] for i in range(0,4)]
# b4 = IC

# P_scan_PC=[53.22,41.24,33.35,28.06]
# P_bloom_PC = [22.46,24.82,25.12,26.49]
# p_edge_PC = [2.43,7.54,9.66,11.09]
# IC_PC = [21.89,26.40,31.87,34.37]

# b11 = [P_scan_PC[i]+P_bloom_PC[i]+p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b22 = [P_bloom_PC[i]+p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b33 = [p_edge_PC[i]+IC_PC[i] for i in range(0,4)]
# b44 = IC_PC

GC=[189.966,43.857,29.580,21.097,18.555]
count=[217.968,60.886,42.594,32.949,29.962]

IG_BS_GC=[113.255,28.173,17.849,13.187,12.155]
IG_ADV_count=[136.704,42.452,32.014,26.621,25.631]

bar1 = plt.bar([i - 0.2 for i in x], count , width = width ,label = "GC" , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black") 

bar2 = plt.bar([i + 0.2for i in x], IG_ADV_count , width = width, label = "IG-BS"  , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black")


bar22 = plt.bar([i + 0.2for i in x],IG_BS_GC , width = width, label = "IG-ADV" , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black",hatch="\\")


bar11 = plt.bar([i - 0.2 for i in x],GC , width = width ,label = "count"  , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black",hatch="/") 







my_y_ticks = np.arange(0, 300, 50)
plt.yticks(my_y_ticks)
# plt.yscale('log')
# plt.ylim(1,2*pow(10,6))

plt.xticks( fontsize=20) #rotation=-15,
plt.yticks(fontsize=20)
plt.ylabel('Time Cost (sec)',fontsize=20)
# plt.xlabel('bi-sk-2005',fontsize=20)
# ,handlelength = 1.6, handletextpad = 0.4, labelspacing = 0, columnspacing=0.4,
#            bbox_to_anchor=(2, 1.2)
legend = ax.legend((bar1,bar11, bar2, bar22, ),
                   ("GC","count","IG-BS","IG-ADV"),
                   loc='upper right',fontsize=16 ,ncol=2,frameon = 0,
                   handlelength = 1.6, handletextpad = 0.4, labelspacing = 0.2, columnspacing=0.5,bbox_to_anchor=(1, 1) )
# frame = legend.get_frame()
# frame.set_alpha(1) 
# frame.set_facecolor('w')
# frame.set_edgecolor('black')
# legend.get_frame().set_facecolor('C0')
plt.xticks(x,labels)
ax.tick_params(axis="x",direction="in", left="off",labelleft="on")
plt.savefig(path+"bbi-sk-2005.pdf", bbox_inches = 'tight')

# %%
fig,ax=plt.subplots()

labels = ["1", "8", "16","24", "32"]

x =list(range(len(labels)))
total_width, n = 0.8,2
width = total_width / n


GC=[546.499,103.072,61.988,45.284,39.159]
count=[590.148,130.539,82.288,65.133,57.525]

IG_BS_GC=[283.090,56.939,34.134,27.588,24.039]
IG_ADV_count=[317.905,79.534,54.989,48.101,44.152]

bar1 = plt.bar([i - 0.2 for i in x], count , width = width ,label = "GC" , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black") 

bar2 = plt.bar([i + 0.2for i in x], IG_ADV_count , width = width, label = "IG-BS"  , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black")


bar22 = plt.bar([i + 0.2for i in x],IG_BS_GC , width = width, label = "IG-ADV" , linewidth=1.5,
               fc = '#e09f3e' ,edgecolor="black",hatch="\\")


bar11 = plt.bar([i - 0.2 for i in x],GC , width = width ,label = "count"  , linewidth=1.5,
               fc = '#fff3b0' ,edgecolor="black",hatch="/") 







my_y_ticks = np.arange(0, 700, 200)
plt.yticks(my_y_ticks)
# plt.yscale('log')
# plt.ylim(1,2*pow(10,6))

plt.xticks( fontsize=20) #rotation=-15,
plt.yticks(fontsize=20)
plt.ylabel('Time Cost (sec)',fontsize=20)
# plt.xlabel('bi-uk-2006-05',fontsize=20)
# ,handlelength = 1.6, handletextpad = 0.4, labelspacing = 0, columnspacing=0.4,
#            bbox_to_anchor=(2, 1.2)
legend = ax.legend((bar1,bar11, bar2, bar22, ),
                   ("GC","count","IG-BS","IG-ADV"),
                   loc='upper right',fontsize=16 ,ncol=2,frameon = 0,
                   handlelength = 1.6, handletextpad = 0.4, labelspacing = 0.2, columnspacing=0.5,bbox_to_anchor=(1, 1) )
# frame = legend.get_frame()
# frame.set_alpha(1) 
# frame.set_facecolor('w')
# frame.set_edgecolor('black')
# legend.get_frame().set_facecolor('C0')
plt.xticks(x,labels)
ax.tick_params(axis="x",direction="in", left="off",labelleft="on")
plt.savefig(path+"bbi-uk-2006-05.pdf", bbox_inches = 'tight')
